# %% [markdown]
# # Be able to investigate client requirements for data analysis
# # 2.3 Qualitative data analysis
#
# Looking at the responces / data we have collected to help us decide what dat we need to fully answer the questions on the future.
#
# * typology (e.g. activities, actions, relationships)
#     - https://www.youtube.com/watch?v=uTXky4C6Je4
#     - https://www.apa.org/pubs/books/essentials-of-ideal-type-analysis-sample-chapter.pdf
#     - Cluster analysis
# * event analysis
# * logical analysis (e.g. flow charts, flow diagrams)

# %% [markdown]
# ## Set up
#
# If running locally or in codespaces you need to run the following in the terminal `python -m textblob.download_corpora lite`

# %%
try:
    import micropip
    await micropip.install(["pyoliteutils", "textblob"])
except:
    pass

# %%
from pyoliteutils import *
import pandas as pd
from textblob import TextBlob

# %%
questionnaire = pd.read_csv("data/eagles/questionnaire.csv")
questionnaire
# Out:
#               Timestamp                                           Are you:  \
# 0     9/1/2021 14:05:26                   A player or member of club staff
# 1      9/2/2021 9:23:44   A current Sheffield Eagles fan who attends games
# 2      9/2/2021 9:25:42   A current Sheffield Eagles fan who attends games
# 3     9/2/2021 10:05:39   A current Sheffield Eagles fan who attends games
# 4     9/2/2021 10:53:30   A current Sheffield Eagles fan who attends games
# ..                  ...                                                ...
# 122   9/27/2021 8:00:25                   A player or member of club staff
# 123  9/27/2021 10:13:35  A Sheffield Eagles fan who no longer attends g...
# 124  9/27/2021 12:35:21   A current Sheffield Eagles fan who attends games
# 125  9/27/2021 22:27:20                                   A former player
# 126   11/4/2021 0:19:42                   A player or member of club staff
#
#     When did you first attend a Sheffield Eagles game?  \
# ...

# %%
memories = questionnaire.loc[:, [col for col in questionnaire.columns if 'memory' in col]]
memories_list = memories.dropna().squeeze().tolist()
memories_list
# Out:
# ['Winning the 1895 Cup',
#  'Challenge Cup win in 98',
#  'Winning league for the second time ',
#  'Challenge cup final 1998',
#  'Back-to-back Grand Final wins.',
#  'Winning at Barrow in my first season to get to Old Trafford.',
#  'Winning promotion in 89 as was the first time we did achieve ',
#  'Winning at Wembley 2019',
#  'Playoff win against swinton 43-18 at old Trafford (first silverware)  followed by Wembley ',
#  'Challenge Cup Final and the Paris weekend',
#  'Challenge cup win',
#  "1895 Cup Final at Wembley (Didn't get there in 1998)",
#  'Wembley 1998',
#  '1998 challenge cup final win',
#  'promotion 1989',
#  'I loved the game against Widnes at bramall lane (just after they were crowned world club champions) they had so many top players in the Widnes team and the Eagles won. I remember this was the moment I fell in love with the sport.\r\nAlso the first time the Eagles beat Wigan was a fantastic game too. ',
#  'Going to Don Valley and the 1895 cup at Wembley ',
# ...

# %%
memories_text = "  ".join(memories_list)
memories_text
# Out:
# "Winning the 1895 Cup  Challenge Cup win in 98  Winning league for the second time   Challenge cup final 1998  Back-to-back Grand Final wins.  Winning at Barrow in my first season to get to Old Trafford.  Winning promotion in 89 as was the first time we did achieve   Winning at Wembley 2019  Playoff win against swinton 43-18 at old Trafford (first silverware)  followed by Wembley   Challenge Cup Final and the Paris weekend  Challenge cup win  1895 Cup Final at Wembley (Didn't get there in 1998)  Wembley 1998  1998 challenge cup final win  promotion 1989  I loved the game against Widnes at bramall lane (just after they were crowned world club champions) they had so many top players in the Widnes team and the Eagles won. I remember this was the moment I fell in love with the sport.\r\nAlso the first time the Eagles beat Wigan was a fantastic game too.   Going to Don Valley and the 1895 cup at Wembley   Challenge Cup win, promotion to top flight in 1989, premiership wins at Old Trafford
# ...

# %%
#What made you first start watching the Sheffield Eagles? 

wordcloud(memories_text)
# Out:
# <img src="https://quickchart.io/wordcloud?format=svg&text=Winning the 1895 Cup  Challenge Cup win in 98  Winning league for the second time   Challenge cup final 1998  Back-to-back Grand Final wins.  Winning at Barrow in my first season to get to Old Trafford.  Winning promotion in 89 as was the first time we did achieve   Winning at Wembley 2019  Playoff win against swinton 43-18 at old Trafford (first silverware)  followed by Wembley   Challenge Cup Final and the Paris weekend  Challenge cup win  1895 Cup Final at Wembley (Didn't get there in 1998)  Wembley 1998  1998 challenge cup final win  promotion 1989  I loved the game against Widnes at bramall lane (just after they were crowned world club champions) they had so many top players in the Widnes team and the Eagles won. I remember this was the moment I fell in love with the sport.
# ...

# %%
blob = TextBlob(memories_text)
blob.tags
# Out:
# [('Winning', 'VBG'),
#  ('the', 'DT'),
#  ('1895', 'CD'),
#  ('Cup', 'NNP'),
#  ('Challenge', 'NNP'),
#  ('Cup', 'NNP'),
#  ('win', 'VBP'),
#  ('in', 'IN'),
#  ('98', 'CD'),
#  ('Winning', 'NNP'),
#  ('league', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('time', 'NN'),
#  ('Challenge', 'NNP'),
#  ('cup', 'VBZ'),
#  ('final', 'JJ'),
#  ('1998', 'CD'),
#  ('Back-to-back', 'JJ'),
#  ('Grand', 'NNP'),
#  ('Final', 'NNP'),
#  ('wins', 'NNS'),
#  ('Winning', 'VBG'),
#  ('at', 'IN'),
#  ('Barrow', 'NNP'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('first', 'JJ'),
#  ('season', 'NN'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('to', 'TO'),
#  ('Old', 'NNP'),
#  ('Trafford', 'NNP'),
#  ('Winning', 'VBG'),
#  ('promotion', 'NN'),
#  ('in', 'IN'),
#  ('89', 'CD'),
#  ('as', 'IN'),
#  ('was', 'VBD'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('we', 'PRP'),
#  ('did', 'VBD'),
#  ('achieve', 'VB'),
#  ('Winning', 'NNP'),
#  ('at', 'IN'),
#  ('Wembley', 'NNP'),
# ...

# %%
nouns = [word.lower() for word, tag in blob.tags if tag in ["NNPS", "NN", "NNS", "NNP", "VBG", "CD", "JJ"]]
nouns
# Out:
# ['winning',
#  '1895',
#  'cup',
#  'challenge',
#  'cup',
#  '98',
#  'winning',
#  'league',
#  'second',
#  'time',
#  'challenge',
#  'final',
#  '1998',
#  'back-to-back',
#  'grand',
#  'final',
#  'wins',
#  'winning',
#  'barrow',
#  'first',
#  'season',
#  'old',
#  'trafford',
#  'winning',
#  'promotion',
#  '89',
#  'first',
#  'time',
#  'winning',
#  'wembley',
#  '2019',
#  'playoff',
#  'win',
#  'swinton',
#  '43-18',
#  'old',
#  'trafford',
#  'first',
#  'silverware',
#  'wembley',
#  'challenge',
#  'cup',
#  'final',
#  'paris',
#  'weekend',
#  'challenge',
#  'cup',
#  'win',
#  '1895',
#  'cup',
#  'final',
#  'wembley',
#  'did',
#  '1998',
#  '1998',
#  '1998',
#  'challenge',
#  'cup',
#  'final',
#  'win',
#  'promotion',
#  '1989',
#  'game',
#  'widnes',
#  'bramall',
#  'lane',
#  'world',
#  'club',
#  'champions',
#  'many',
#  'top',
#  'players',
#  'widnes',
#  'team',
#  'eagles',
#  'moment',
#  'love',
#  'sport',
#  'first',
#  'time',
# ...

# %%
wordcloud(" ".join(nouns))
# Out:
# <img src="https://quickchart.io/wordcloud?format=svg&text=winning 1895 cup challenge cup 98 winning league second time challenge final 1998 back-to-back grand final wins winning barrow first season old trafford winning promotion 89 first time winning wembley 2019 playoff win swinton 43-18 old trafford first silverware wembley challenge cup final paris weekend challenge cup win 1895 cup final wembley did 1998 1998 1998 challenge cup final win promotion 1989 game widnes bramall lane world club champions many top players widnes team eagles moment love sport first time eagles beat wigan fantastic game going don valley 1895 cup wembley challenge cup win promotion flight 1989 premiership wins old trafford camaraderie players supporters challenge final winning 1895 cup wembley wembley 1998 98 challenge cup playing australia don valley challenge cup win wigan challenge cup victory recent wembley win winning challenge cup back champions team wee winning national league 2 promotional final 200
# ...

# %%
def wordcloud_from_column(df, colcontains):
    memories = df.loc[:, [col for col in df.columns if colcontains in col]]
    memories_list = memories.dropna().squeeze().tolist()
    memories_list
    memories_text = "  ".join(memories_list)
    #memories_text
    blob = TextBlob(memories_text)
    #blob.tags
    nouns = [word.lower() for word, tag in blob.tags if tag in ["NNPS", "NN", "NNS", "NNP", "VBG", "CD", "JJ"]]
    #nouns
    return  wordcloud(" ".join(nouns))

wordcloud_from_column(questionnaire, "memory")
# Out:
# <img src="https://quickchart.io/wordcloud?format=svg&text=winning 1895 cup challenge cup 98 winning league second time challenge final 1998 back-to-back grand final wins winning barrow first season old trafford winning promotion 89 first time winning wembley 2019 playoff win swinton 43-18 old trafford first silverware wembley challenge cup final paris weekend challenge cup win 1895 cup final wembley did 1998 1998 1998 challenge cup final win promotion 1989 game widnes bramall lane world club champions many top players widnes team eagles moment love sport first time eagles beat wigan fantastic game going don valley 1895 cup wembley challenge cup win promotion flight 1989 premiership wins old trafford camaraderie players supporters challenge final winning 1895 cup wembley wembley 1998 98 challenge cup playing australia don valley challenge cup win wigan challenge cup victory recent wembley win winning challenge cup back champions team wee winning national league 2 promotional final 200
# ...

# %%
questionnaire.columns
# Out:
# Index(['Timestamp', 'Are you:',
#        'When did you first attend a Sheffield Eagles game?',
#        'Would you class yourself as:',
#        'When did you last attend a game (home or away)?',
#        'What made you first start watching the Sheffield Eagles?',
#        'What is your favourite memory of the Sheffield Eagles? ',
#        'Do you have any Sheffield Eagles memorabilia - old photographs, match day programmes, stickers, shirts, press cuttings etc - that you'd be willing to share with the project? If so please provide brief details. ',
#        'Can you quickly describe what the Sheffield Eagles means to you, this could be because you are a supporter, a player, a sponsor or an organisation that works with the Club. ',
#        'What are some of the stories that are part of the history of the Sheffield Eagles that you think deserve sharing to a wider audience? ',
# ...

# %%
wordcloud_from_column(questionnaire, "that you think deserve sharing")
# Out:
# <img src="https://quickchart.io/wordcloud?format=svg&text=1895 cup win supporters helping club late 2016 journey / club number players playing game thanks previous youth development system good newer fans early days club ground due major sponsor going bust endurance little support council other organisations years 2014-2017 different ground year club going finishing top four 2015 struggle alive one occasion hahah many re-birth survival huddersfield amalgamation 6 years support eagles 6 different 'home venues 2 sheffield story sustained determination derek bridgeman person significant disability making massive impact tough sport mostly unrepeatable playing australia lost first 20 minutes competitive match loyal following eagles informed passionate close connections fans determination 2 wembley final games don valley stadium era place home pitch happy memories running don valley money lee jackson club widnes game bramall lane yorkshire cup final past present players amazing players clu
# ...

# %%
wordcloud_from_column(questionnaire, "memorabilia")
# Out:
# <img src="https://quickchart.io/wordcloud?format=svg&text=yes lots shirts lots photos got replica shirts programmes shirt nothing past programmes match reports loads collection programmes got programme bits pieces eagles soar press cuttings challenge cup paul broadbent captain mark aston lance todd winner unique things loads sorts things dad loft time programmes cuttings rugby league archive programmes yes format programmes shirts badges photos share afterwards badges jewelry shirts scarves car stickers programmes shares news papers books league leaders medal photographs lot tales stories club challenges things times lot fun laughter events lot programmes programmes season yes collection programmes programmes home plenty ticket stubs season ticket booklets programmes programmes season yes i club anything no yes shirt articles sheffield university steel press newspaper merger cutting eagles internet message board team sheffield beagles forgers beagles shirt home look books etc possibl
# ...
